# %% [markdown]
# # CASH-4464: Expand evaluation window of ARIMA market trend predictions
#
# ### Goal:
#
# For the evaluation of the predicted rate direction (up, stable, down), expand the evaluation window to better assess how the algorithm performs at different points in time and market conditions.

# %%
# Load required packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import seaborn as sns

sns.set()


# import necessary libraries
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
from datetime import timedelta

## display df side by side
from IPython.display import HTML

# Supressing warnings
import warnings

warnings.filterwarnings("ignore")

# %%
# Format settings:
pd.set_option("display.float_format", lambda x: "%.4f" % x)

# %% [markdown]
# ### Get TRAC rates from selected lanes V0
#
# TRAC lanes were originally denified on CASH-4305:
#
# You can either extract then from a s3 file or trino table.

# %%
# ## Extract files from aws S3 and save it on a file path
! aws s3 cp  s3://loadsmart-data-science/pricing-analysis/CASH-4305/df_trac_selected_lanes_rates.csv .

### Table trino: s3_silver.trac.lanes
# Out:
# Completed 256.0 KiB/22.6 MiB (186.3 KiB/s) with 1 file(s) remaining
# Completed 512.0 KiB/22.6 MiB (358.3 KiB/s) with 1 file(s) remaining
# Completed 768.0 KiB/22.6 MiB (512.3 KiB/s) with 1 file(s) remaining
# Completed 1.0 MiB/22.6 MiB (657.0 KiB/s) with 1 file(s) remaining
# Completed 1.2 MiB/22.6 MiB (777.2 KiB/s) with 1 file(s) remaining
# Completed 1.5 MiB/22.6 MiB (885.1 KiB/s) with 1 file(s) remaining
# Completed 1.8 MiB/22.6 MiB (1.0 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/22.6 MiB (1.1 MiB/s) with 1 file(s) remaining
# Completed 2.2 MiB/22.6 MiB (1.2 MiB/s) with 1 file(s) remaining
# Completed 2.5 MiB/22.6 MiB (1.3 MiB/s) with 1 file(s) remaining
# Completed 2.8 MiB/22.6 MiB (1.3 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/22.6 MiB (1.4 MiB/s) with 1 file(s) remaining
# Completed 3.2 MiB/22.6 MiB (1.5 MiB/s) with 1 file(s) remaining
# Completed 3.5 MiB/22.6 MiB (1.6 MiB/s) with 1 file(s) remaining
# Completed 3.8 MiB/22.6 MiB (1.7 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/22.6 MiB (1.7 MiB/s) with 1 file(s) remaining
# Completed 4.2 MiB/22.6 MiB (1.8 MiB/s) with 1 file(s) remaining
# Completed 4.5 MiB/22.6 MiB (1.9 MiB/s) with 1 file(s) remaining
# Completed 4.8 MiB/22.6 MiB (1.9 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/22.6 MiB (2.0 MiB/s) with 1 file(s) remaining
# Completed 5.2 MiB/22.6 MiB (2.0 MiB/s) with 1 file(s) remaining
# Completed 5.5 MiB/22.6 MiB (2.0 MiB/s) with 1 file(s) remaining
# Completed 5.8 MiB/22.6 MiB (2.0 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/22.6 MiB (2.0 MiB/s) with 1 file(s) remaining
# Completed 6.2 MiB/22.6 MiB (2.1 MiB/s) with 1 file(s) remaining
# Completed 6.5 MiB/22.6 MiB (2.1 MiB/s) with 1 file(s) remaining
# Completed 6.8 MiB/22.6 MiB (2.1 MiB/s) with 1 file(s) remaining
# Completed 7.0 MiB/22.6 MiB (2.2 MiB/s) with 1 file(s) remaining
# Completed 7.2 MiB/22.6 MiB (2.2 MiB/s) with 1 file(s) remaining
# Completed 7.5 MiB/22.6 MiB (2.2 MiB/s) with 1 file(s) remaining
# Completed 7.8 MiB/22.6 MiB (2.3 MiB/s) with 1 file(s) remaining
# Completed 8.0 MiB/22.6 MiB (2.3 MiB/s) with 1 file(s) remaining
# Completed 8.2 MiB/22.6 MiB (2.3 MiB/s) with 1 file(s) remaining
# Completed 8.5 MiB/22.6 MiB (2.3 MiB/s) with 1 file(s) remaining
# Completed 8.8 MiB/22.6 MiB (2.3 MiB/s) with 1 file(s) remaining
# Completed 9.0 MiB/22.6 MiB (2.3 MiB/s) with 1 file(s) remaining
# Completed 9.2 MiB/22.6 MiB (2.3 MiB/s) with 1 file(s) remaining
# Completed 9.5 MiB/22.6 MiB (2.3 MiB/s) with 1 file(s) remaining
# Completed 9.8 MiB/22.6 MiB (2.4 MiB/s) with 1 file(s) remaining
# Completed 10.0 MiB/22.6 MiB (2.4 MiB/s) with 1 file(s) remaining
# Completed 10.2 MiB/22.6 MiB (2.4 MiB/s) with 1 file(s) remaining
# Completed 10.5 MiB/22.6 MiB (2.4 MiB/s) with 1 file(s) remaining
# Completed 10.8 MiB/22.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 11.0 MiB/22.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 11.2 MiB/22.6 MiB (2.4 MiB/s) with 1 file(s) remaining
# Completed 11.5 MiB/22.6 MiB (2.4 MiB/s) with 1 file(s) remaining
# Completed 11.8 MiB/22.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 12.0 MiB/22.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 12.2 MiB/22.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 12.5 MiB/22.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 12.8 MiB/22.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 13.0 MiB/22.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 13.2 MiB/22.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 13.5 MiB/22.6 MiB (2.6 MiB/s) with 1 file(s) remaining
# Completed 13.8 MiB/22.6 MiB (2.7 MiB/s) with 1 file(s) remaining
# Completed 14.0 MiB/22.6 MiB (2.7 MiB/s) with 1 file(s) remaining
# Completed 14.2 MiB/22.6 MiB (2.7 MiB/s) with 1 file(s) remaining
# Completed 14.5 MiB/22.6 MiB (2.7 MiB/s) with 1 file(s) remaining
# Completed 14.8 MiB/22.6 MiB (2.7 MiB/s) with 1 file(s) remaining
# Completed 15.0 MiB/22.6 MiB (2.8 MiB/s) with 1 file(s) remaining
# Completed 15.2 MiB/22.6 MiB (2.8 MiB/s) with 1 file(s) remaining
# Completed 15.5 MiB/22.6 MiB (2.8 MiB/s) with 1 file(s) remaining
# Completed 15.8 MiB/22.6 MiB (2.8 MiB/s) with 1 file(s) remaining
# Completed 16.0 MiB/22.6 MiB (2.8 MiB/s) with 1 file(s) remaining
# Completed 16.2 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 16.5 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 16.8 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 17.0 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 17.2 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 17.5 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 17.8 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 18.0 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 18.2 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 18.5 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 18.8 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 19.0 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 19.2 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 19.4 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 19.6 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 19.9 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 20.1 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 20.4 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 20.6 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 20.9 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 21.1 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 21.4 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 21.6 MiB/22.6 MiB (3.0 MiB/s) with 1 file(s) remaining
# Completed 21.9 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 22.1 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 22.4 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# Completed 22.6 MiB/22.6 MiB (2.9 MiB/s) with 1 file(s) remaining
# download: s3://loadsmart-data-science/pricing-analysis/CASH-4305/df_trac_selected_lanes_rates.csv to .\df_trac_selected_lanes_rates.csv

# %%
## Get selected Dry Van lanes previously defined
df_trac = pd.read_csv("df_trac_selected_lanes_rates.csv")
df_trac.set_index("data_timestamp", inplace=True)

## fill in missing data
df_trac = df_trac.fillna(method="ffill").fillna(method="bfill")

# %% [markdown]
# ## Select a few lanes to run ARIMA:
#
# #### The chosen lanes are among the SG TOP Lanes previously identified (CASH-4373:)

# %%
df_arima = df_trac[
    [
        "442-286",
        "410-601",
        "917-841",
        "770-300",
        "432-296",
        "301-945",
        "231-194",
        "372-282",
        "780-770",
        "303-752",
    ]
]
# df_arima = df_trac[["442-286", "410-601", "917-841", "770-300"]]
df_arima.index = pd.to_datetime(df_arima.index)

# Get datapoints of every Friday
df_arima_f = df_arima[df_arima.index.day_name() == "Friday"]

# %% [markdown]
# ## ARIMA Modelling:
#
# ### Let's loop ARIMA for all selected lanes

# %%
def get_forecast_lane(data, n_periods):
    # Initialize empty lists to store forecast data
    data_fc = []
    data_lower = []
    data_upper = []
    data_aic = []
    data_order = []
    data_fitted = []

    # Iterate over columns in data
    for lane in data.columns:
        # Fit an ARIMA model using the auto_arima function
        data_actual = data[lane]
        model = pm.auto_arima(
            data_actual,
            # start_p=1,
            # start_q=1, # had
            max_p=3,
            max_q=3,  # maximum p and q
            test="adf",  # use adftest to find optimal 'd'
            d=None,  # let model determine 'd'
            #   seasonal=seasonal,  # TRUE if seasonal series
            # m=7,  # frequency of series
            # D=None,  # let model determine 'D'
            trace=False,  # Whether to print status on the fits
            error_action="ignore",
            suppress_warnings=True,
            stepwise=True,
        )

        # Generate forecast and confidence intervals for n_periods into the future
        fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)
        index_of_fc = pd.date_range(
            pd.to_datetime(df_arima_f.index[-1]) + timedelta(days=6),
            periods=n_periods,
            freq="W-FRI",
        )

        # Append forecast data to lists
        data_fc.append(fc)
        data_lower.append(confint[:, 0])
        data_upper.append(confint[:, 1])
        data_aic.append(model.aic())
        data_order.append(model.order)
        data_fitted.append(
            model.fittedvalues()
        )  # Notice that auto arima applies one-step ahead predictions

        # Create dataframes for forecast, lower bound, and upper bound and model statistics
        df_fc = pd.DataFrame(index=index_of_fc)
        df_lower = pd.DataFrame(index=index_of_fc)
        df_upper = pd.DataFrame(index=index_of_fc)
        df_aic = pd.DataFrame()
        df_order = pd.DataFrame()
        df_fitted = pd.DataFrame(index=data_actual.index)

    # Populate dataframes with fit results
    i = 0
    for lane in data.columns:
        df_fc[lane] = data_fc[i][:]
        df_lower[lane] = data_lower[i][:]
        df_upper[lane] = data_upper[i][:]
        df_aic[lane] = data_aic[i]
        df_order[lane] = data_order[i]
        df_fitted[lane] = data_fitted[i][:].iloc[1:]
        i = i + 1

    # Need to drop first row of fitted data - all row value equals to zero because of the recursive ARIMA process
    df_fitted = df_fitted.iloc[1:]
    # Rename df_order index to match ARI<MA hyperparamethers
    df_order = df_order.rename(index={0: "p", 1: "d", 2: "q"})

    return df_fc, df_lower, df_upper, df_aic, df_fitted, df_order

# %%
df_fc, df_lower, df_upper, df_aic, df_fitted, df_order = get_forecast_lane(
    data=df_arima_f, n_periods=1
)

# %% [markdown]
# ### Best model selection based on AIC Criteria

# %%
df_order
# Out:
#    442-286  410-601  917-841  770-300  432-296  301-945  231-194  372-282  \
# p        1        0        0        2        1        2        2        2
# d        1        1        1        1        1        1        1        1
# q        2        2        2        0        0        3        2        1
#
#    780-770  303-752
# p        3        3
# d        1        1
# q        0        3

# %% [markdown]
# ## Evaluate market trends

# %%
### Weekly change
def weekly_change(df):
    # df_delta = df.copy()
    df_week_delta = df.diff()
    # # Drop the first row NaN Values
    df_week_delta = df_week_delta.iloc[1:]
    return df_week_delta


### Set market directional trends rule
def market_trend(x):
    if x >= 0.015:
        return "up"
    if x <= -0.015:
        return "down"
    else:
        return "stable"

# %%
# Get weekly changes
df_delta = weekly_change(df_arima_f)

# Apply market trend rules
df_delta_trend = df_delta.applymap(market_trend)

# %% [markdown]
# ### 2. In-sample TRAC-fitted values cross check
#
# Notice that I will be comparing (TRAC) with the forecasted/Fitted Values (t+1).
#
# That is, to verify if the predicted values ​​were able to generate the correct market trend, I calculate the difference between forecasted (t+1) and the actual value in t to obtain the market direction.

# %%
### Extract daily market trend: Forecsted (t+1) - TRAC real data (t)
df_trac_fitted = df_fitted - df_arima_f.shift(+1)
df_trac_fitted = df_trac_fitted.iloc[1:]

# %%
# Apply market trend rules
df_trac_fitted_trend = df_trac_fitted.applymap(market_trend)
df_trac_fitted_trend.tail(5)
# Out:
#                442-286 410-601 917-841 770-300 432-296 301-945 231-194  \
# data_timestamp
# 2023-04-21      stable  stable  stable  stable  stable  stable    down
# 2023-04-28      stable    down  stable    down  stable  stable  stable
# 2023-05-05      stable  stable    down  stable    down  stable      up
# 2023-05-12      stable      up  stable      up    down  stable  stable
# 2023-05-19        down    down  stable    down    down  stable  stable
#
#                372-282 780-770 303-752
# data_timestamp
# 2023-04-21        down  stable    down
# 2023-04-28      stable  stable  stable
# 2023-05-05        down  stable  stable
# 2023-05-12          up      up      up
# 2023-05-19          up  stable  stable

# %% [markdown]
# #### Concatenate both dfs to further analysis

# %%
df_all = pd.concat(
    [df_delta_trend, df_trac_fitted_trend],
    axis="columns",
    keys=["TRAC", "ARIMA"],
)

# %%
df_final = df_all.swaplevel(axis="columns")
df_final = df_final[(sorted(df_final.columns))].reset_index()
df_final.set_index("data_timestamp", inplace=True)
df_final
# Out:
#                231-194         301-945         303-752         372-282        \
#                  ARIMA    TRAC   ARIMA    TRAC   ARIMA    TRAC   ARIMA  TRAC
# data_timestamp
# 2019-01-11      stable    down  stable    down  stable      up  stable  down
# 2019-01-18      stable    down  stable      up  stable    down    down  down
# 2019-01-25        down    down  stable    down    down    down    down  down
# 2019-02-01        down    down  stable    down    down  stable    down  down
# 2019-02-08      stable    down  stable  stable  stable    down    down    up
# ...                ...     ...     ...     ...     ...     ...     ...   ...
# 2023-04-21        down  stable  stable    down    down  stable    down  down
# 2023-04-28      stable      up  stable  stable  stable    down  stable  down
# 2023-05-05          up      up  stable  stable  stable      up    down    up
# 2023-05-12      stable    down  stable  stable      up  stable      up  down
# 2023-05-19      stable  stable  stable  stable  stable      up      up    up
#
#                410-601         432-296       442-286         770-300          \
#                  ARIMA    TRAC   ARIMA  TRAC   ARIMA    TRAC   ARIMA    TRAC
# data_timestamp
# 2019-01-11      stable  stable  stable  down  stable    down  stable  stable
# 2019-01-18      stable    down    down  down    down    down  stable    down
# 2019-01-25        down  stable    down  down    down    down  stable    down
# 2019-02-01      stable    down    down  down    down    down    down    down
# 2019-02-08      stable    down    down  down    down    down    down    down
# ...                ...     ...     ...   ...     ...     ...     ...     ...
# 2023-04-21      stable    down  stable  down  stable    down  stable    down
# 2023-04-28        down      up  stable  down  stable  stable    down    down
# 2023-05-05      stable      up    down  down  stable    down  stable      up
# 2023-05-12          up    down    down  down  stable    down      up    down
# 2023-05-19        down  stable    down    up    down  stable    down  stable
#
#                780-770         917-841
#                  ARIMA    TRAC   ARIMA    TRAC
# data_timestamp
# 2019-01-11      stable      up  stable    down
# 2019-01-18      stable    down  stable    down
# 2019-01-25      stable    down    down    down
# 2019-02-01        down    down    down    down
# 2019-02-08          up    down    down  stable
# ...                ...     ...     ...     ...
# 2023-04-21      stable    down  stable  stable
# 2023-04-28      stable  stable  stable    down
# 2023-05-05      stable      up    down    down
# 2023-05-12          up      up  stable      up
# 2023-05-19      stable    down  stable      up
#
# [228 rows x 20 columns]

# %% [markdown]
# ## Confusion Matrix analysis
#
# #### All data sample

# %%
### Add a suffix to better visualize results in the confusion matrix
df_trac_fitted_trend.columns = [str(col) + "_f" for col in df_trac_fitted_trend.columns]

# %% [markdown]
# To better assess market predictions results, it was built a confusion matrix. It shows how many prediction are correct and incorrect per class (market trends).
#
# It helps in understanding the classes that are being confused by model as other class.

# %%
def conf_matrix(df1, lane1, df2, lane2, lane_name):
    df_ct = pd.crosstab(df1[lane1], df2[lane2], normalize="all")

    # Calculate scenarios based on matrix element position
    trace = np.trace(df_ct).round(2)
    stable_trend = (df_ct.iat[1, 0] + df_ct.iat[1, 2]).round(2)
    trend_stable = (df_ct.iat[0, 1] + df_ct.iat[2, 1]).round(2)
    false_positives = (df_ct.iat[2, 0] + df_ct.iat[0, 2]).round(2)

    ### Creaate a df of the results
    # assign data of lists.
    data = {lane_name: [trace, stable_trend, trend_stable, false_positives]}
    # Creates pandas DataFrame.
    df_values = pd.DataFrame(
        data, index=["Trace", "Stable_Trend", "Trend_Stable", "False Positives"]
    )

    # print the data
    return df_values

# %%
df_cf_1 = conf_matrix(
    df_delta_trend, "442-286", df_trac_fitted_trend, "442-286_f", "442-286"
)

df_cf_2 = conf_matrix(
    df_delta_trend, "410-601", df_trac_fitted_trend, "410-601_f", "410-601"
)

df_cf_3 = conf_matrix(
    df_delta_trend, "917-841", df_trac_fitted_trend, "917-841_f", "917-841"
)

df_cf_4 = conf_matrix(
    df_delta_trend, "770-300", df_trac_fitted_trend, "770-300_f", "770-300"
)

df_cf_5 = conf_matrix(
    df_delta_trend, "432-296", df_trac_fitted_trend, "432-296_f", "432-296"
)

df_cf_6 = conf_matrix(
    df_delta_trend, "301-945", df_trac_fitted_trend, "301-945_f", "301-945"
)

df_cf_7 = conf_matrix(
    df_delta_trend, "231-194", df_trac_fitted_trend, "231-194_f", "231-194"
)

df_cf_8 = conf_matrix(
    df_delta_trend, "372-282", df_trac_fitted_trend, "372-282_f", "372-282"
)

df_cf_9 = conf_matrix(
    df_delta_trend, "780-770", df_trac_fitted_trend, "780-770_f", "780-770"
)

df_cf_10 = conf_matrix(
    df_delta_trend, "303-752", df_trac_fitted_trend, "303-752_f", "303-752"
)

# %%
### Display results side by side
def side_by_side(*dfs):
    html = '<div style="display:flex">'
    for df in dfs:
        html += '<div style="margin-right: 2em">'
        html += df.to_html()
        html += "</div>"
    html += "</div>"
    display(HTML(html))


print("All datapoints")
side_by_side(df_cf_1, df_cf_2, df_cf_3, df_cf_4, df_cf_5)

side_by_side(df_cf_6, df_cf_7, df_cf_8, df_cf_9, df_cf_10)
# Out:
# All datapoints
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>442-286</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4900</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2900</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1500</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>410-601</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4800</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0900</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2800</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1500</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>917-841</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4700</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0800</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2500</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1900</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>770-300</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.3900</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.4800</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0700</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>432-296</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.6100</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0900</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.1600</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1400</td>
#     </tr>
#   </tbody>
# </table></div></div>
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>301-945</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.3900</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0800</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.4600</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0700</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>231-194</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4000</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.3200</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.2000</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>372-282</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4200</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.3200</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1800</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>780-770</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.3100</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.4300</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1800</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>303-752</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4700</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.1100</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.3400</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0800</td>
#     </tr>
#   </tbody>
# </table></div></div>

# %% [markdown]
# Preliminary findings:
#
# * Roughly, in about 50% of cases, the market direction strategy.
#
# * Regardless of the lane, antagonistic values ​​occurred in less than 15% of the all cases $\rightarrow $ Consequently, the probability of committing a serious error is relatively low.
#
# * Given the complexity of the market and the source of primary data, the strategy proved to be credible.
#
# ## Select different data range to evaluate trends in different economic/freight contexts
#
# ### Range 1: 2019-11-22 - 2020-10-02

# %%
mask = (df_delta_trend.index >= "2019-11-22") & (df_delta_trend.index <= "2020-10-02")
df_delta_trend_range_1 = df_delta_trend.loc[mask]
df_trac_fitted_trend_range_1 = df_trac_fitted_trend.loc[mask]

# %%
### Calculate confusion matrix

df_cf_1 = conf_matrix(
    df_delta_trend_range_1,
    "442-286",
    df_trac_fitted_trend_range_1,
    "442-286_f",
    "442-286",
)

df_cf_2 = conf_matrix(
    df_delta_trend_range_1,
    "410-601",
    df_trac_fitted_trend_range_1,
    "410-601_f",
    "410-601",
)

df_cf_3 = conf_matrix(
    df_delta_trend_range_1,
    "917-841",
    df_trac_fitted_trend_range_1,
    "917-841_f",
    "917-841",
)

df_cf_4 = conf_matrix(
    df_delta_trend_range_1,
    "770-300",
    df_trac_fitted_trend_range_1,
    "770-300_f",
    "770-300",
)

df_cf_5 = conf_matrix(
    df_delta_trend_range_1,
    "432-296",
    df_trac_fitted_trend_range_1,
    "432-296_f",
    "432-296",
)

df_cf_6 = conf_matrix(
    df_delta_trend_range_1,
    "301-945",
    df_trac_fitted_trend_range_1,
    "301-945_f",
    "301-945",
)

df_cf_7 = conf_matrix(
    df_delta_trend_range_1,
    "231-194",
    df_trac_fitted_trend_range_1,
    "231-194_f",
    "231-194",
)

df_cf_8 = conf_matrix(
    df_delta_trend_range_1,
    "372-282",
    df_trac_fitted_trend_range_1,
    "372-282_f",
    "372-282",
)

df_cf_9 = conf_matrix(
    df_delta_trend_range_1,
    "780-770",
    df_trac_fitted_trend_range_1,
    "780-770_f",
    "780-770",
)

df_cf_10 = conf_matrix(
    df_delta_trend_range_1,
    "303-752",
    df_trac_fitted_trend_range_1,
    "303-752_f",
    "303-752",
)

# %% [markdown]
# ### Range 2: 2021-12-31 - 2022-08-01

# %%
mask_2 = (df_delta_trend.index >= "2021-12-01") & (df_delta_trend.index <= "2022-12-15")
df_delta_trend_range_2 = df_delta_trend.loc[mask_2]
df_trac_fitted_trend_range_2 = df_trac_fitted_trend.loc[mask_2]

# %%
### Calculate confusion matrix

df_cf_1_2 = conf_matrix(
    df_delta_trend_range_2,
    "442-286",
    df_trac_fitted_trend_range_2,
    "442-286_f",
    "442-286",
)

df_cf_2_2 = conf_matrix(
    df_delta_trend_range_2,
    "410-601",
    df_trac_fitted_trend_range_2,
    "410-601_f",
    "410-601",
)

df_cf_3_2 = conf_matrix(
    df_delta_trend_range_2,
    "917-841",
    df_trac_fitted_trend_range_2,
    "917-841_f",
    "917-841",
)

df_cf_4_2 = conf_matrix(
    df_delta_trend_range_2,
    "770-300",
    df_trac_fitted_trend_range_2,
    "770-300_f",
    "770-300",
)

df_cf_5_2 = conf_matrix(
    df_delta_trend_range_2,
    "432-296",
    df_trac_fitted_trend_range_2,
    "432-296_f",
    "432-296",
)

df_cf_6_2 = conf_matrix(
    df_delta_trend_range_2,
    "301-945",
    df_trac_fitted_trend_range_2,
    "301-945_f",
    "301-945",
)

df_cf_7_2 = conf_matrix(
    df_delta_trend_range_2,
    "231-194",
    df_trac_fitted_trend_range_2,
    "231-194_f",
    "231-194",
)

df_cf_8_2 = conf_matrix(
    df_delta_trend_range_2,
    "372-282",
    df_trac_fitted_trend_range_2,
    "372-282_f",
    "372-282",
)

df_cf_9_2 = conf_matrix(
    df_delta_trend_range_2,
    "780-770",
    df_trac_fitted_trend_range_2,
    "780-770_f",
    "780-770",
)

df_cf_10_2 = conf_matrix(
    df_delta_trend_range_2,
    "303-752",
    df_trac_fitted_trend_range_2,
    "303-752_f",
    "303-752",
)

# %% [markdown]
# ### Range 3: 2022-12-23 - 2023-02-31

# %%
mask_3 = (df_delta_trend.index >= "2022-12-23") & (df_delta_trend.index <= "2023-03-31")
df_delta_trend_range_3 = df_delta_trend.loc[mask_3]
df_trac_fitted_trend_range_3 = df_trac_fitted_trend.loc[mask_3]

# %%
### Calculate confusion matrix

df_cf_1_3 = conf_matrix(
    df_delta_trend_range_3,
    "442-286",
    df_trac_fitted_trend_range_3,
    "442-286_f",
    "442-286",
)

df_cf_2_3 = conf_matrix(
    df_delta_trend_range_3,
    "410-601",
    df_trac_fitted_trend_range_3,
    "410-601_f",
    "410-601",
)

df_cf_3_3 = conf_matrix(
    df_delta_trend_range_3,
    "917-841",
    df_trac_fitted_trend_range_3,
    "917-841_f",
    "917-841",
)

df_cf_4_3 = conf_matrix(
    df_delta_trend_range_3,
    "770-300",
    df_trac_fitted_trend_range_3,
    "770-300_f",
    "770-300",
)

df_cf_5_3 = conf_matrix(
    df_delta_trend_range_3,
    "432-296",
    df_trac_fitted_trend_range_3,
    "432-296_f",
    "432-296",
)

df_cf_6_3 = conf_matrix(
    df_delta_trend_range_3,
    "301-945",
    df_trac_fitted_trend_range_3,
    "301-945_f",
    "301-945",
)

df_cf_7_3 = conf_matrix(
    df_delta_trend_range_3,
    "231-194",
    df_trac_fitted_trend_range_3,
    "231-194_f",
    "231-194",
)

df_cf_8_3 = conf_matrix(
    df_delta_trend_range_3,
    "372-282",
    df_trac_fitted_trend_range_3,
    "372-282_f",
    "372-282",
)

df_cf_9_3 = conf_matrix(
    df_delta_trend_range_3,
    "780-770",
    df_trac_fitted_trend_range_3,
    "780-770_f",
    "780-770",
)

df_cf_10_3 = conf_matrix(
    df_delta_trend_range_3,
    "303-752",
    df_trac_fitted_trend_range_3,
    "303-752_f",
    "303-752",
)

# %%
print("\nRANGE 1: 2019-11-22 - 2020-10-02")
side_by_side(df_cf_1, df_cf_2, df_cf_3, df_cf_4, df_cf_5)
side_by_side(df_cf_6, df_cf_7, df_cf_8, df_cf_9, df_cf_10)

print("\nRANGE 2: 2021-12-31 - 2022-08-01")
side_by_side(df_cf_1_2, df_cf_2_2, df_cf_3_2, df_cf_4_2, df_cf_5_2)
side_by_side(df_cf_6_2, df_cf_7_2, df_cf_8_2, df_cf_9_2, df_cf_10_2)

print("\nRANGE 3: 2022-12-23 - 2023-02-31")
side_by_side(df_cf_1_3, df_cf_2_3, df_cf_3_3, df_cf_4_3, df_cf_5_3)
side_by_side(df_cf_6_3, df_cf_7_3, df_cf_8_3, df_cf_9_3, df_cf_10_3)
# Out:
# RANGE 1: 2019-11-22 - 2020-10-02
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>442-286</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.5200</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0400</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2600</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1700</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>410-601</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.6500</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0200</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2000</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1300</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>917-841</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.5900</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0400</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.1500</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.2200</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>770-300</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.5400</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0400</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.3700</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0400</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>432-296</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.8000</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0400</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0900</td>
#     </tr>
#   </tbody>
# </table></div></div>
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>301-945</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.3500</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.1300</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.4300</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0900</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>231-194</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.3900</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.3300</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.2200</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>372-282</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.6300</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2600</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0400</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>780-770</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.3900</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.1100</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2600</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.2400</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>303-752</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.6500</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0400</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2800</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0200</td>
#     </tr>
#   </tbody>
# </table></div></div>
# RANGE 2: 2021-12-31 - 2022-08-01
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>442-286</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.6100</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0200</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.1900</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1900</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>410-601</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.5400</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0900</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2200</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1500</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>917-841</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4800</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0600</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.3000</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1700</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>770-300</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4400</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0600</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.4400</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0600</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>432-296</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4800</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.1100</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.1900</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.2200</td>
#     </tr>
#   </tbody>
# </table></div></div>
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>301-945</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.3900</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0900</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.4300</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0900</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>231-194</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4300</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2600</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.2400</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>372-282</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4300</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0200</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.3100</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.2400</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>780-770</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.2400</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0900</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.5200</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1500</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>303-752</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4800</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.1500</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2600</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1100</td>
#     </tr>
#   </tbody>
# </table></div></div>
# RANGE 3: 2022-12-23 - 2023-02-31
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>442-286</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.6000</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.1300</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.1300</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1300</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>410-601</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.6700</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0000</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2000</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1300</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>917-841</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4000</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2000</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.3300</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>770-300</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4000</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.1300</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.4700</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0000</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>432-296</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.7300</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.1300</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0700</td>
#     </tr>
#   </tbody>
# </table></div></div>
# <div style="display:flex"><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>301-945</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4000</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0000</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.5300</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0700</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>231-194</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.2700</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.1300</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.5300</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0700</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>372-282</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.4700</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.3300</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1300</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>780-770</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.3300</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.4700</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.1300</td>
#     </tr>
#   </tbody>
# </table></div><div style="margin-right: 2em"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>303-752</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trace</th>
#       <td>0.6000</td>
#     </tr>
#     <tr>
#       <th>Stable_Trend</th>
#       <td>0.0700</td>
#     </tr>
#     <tr>
#       <th>Trend_Stable</th>
#       <td>0.2700</td>
#     </tr>
#     <tr>
#       <th>False Positives</th>
#       <td>0.0700</td>
#     </tr>
#   </tbody>
# </table></div></div>

# %% [markdown]
# Preliminary findings:
#
# * It is evident how economc enviroment affect market classes distribution.
#
# * In different scenarios, the probability of the model incurring major errors remained low.
#
# * Degree of uncertainty/risk in forecasted projectrions is influenced by the context of the lanes. Lanes with a low trace value may be influenced by intrinsic features to the price series (number of providers, dispersion).
#
# ## Weekly analysis
#
# But remember, we are going to evaluate on a weekly basis, so let's asess how good are the forecasted values on a weekly basis.
#
# Randomly, we have chosen 6 datapoints to evaluate:
#
# * 2019-09-13
# * 2020-07-10
# * 2021-08-27
# * 2022-04-22
# * 2023-03-17
# * 2023-05-19

# %%
df_week = df_final.loc[
    pd.DatetimeIndex(
        [
            "2019-09-13",
            "2020-07-10",
            "2021-08-27",
            "2022-04-22",
            "2023-03-17",
            "2023-05-19",
        ]
    )
]

# %% [markdown]
# ### Evaluate when ARIMA and TRAC market trends diverge on selected weeks

# %%
def highlight_diff(data, color="red"):
    attr = "background-color: {}".format(color)
    other = data.xs("ARIMA", axis="columns", level=-1)
    return pd.DataFrame(
        # evaluate inequality over the column axis
        np.where(data.ne(other, level=0), attr, ""),
        index=data.index,
        columns=data.columns,
    )


teste = df_week.style.apply(highlight_diff, axis=None)
teste
# Out:
# <style type="text/css">
# #T_92443_row0_col1, #T_92443_row0_col15, #T_92443_row0_col17, #T_92443_row0_col19, #T_92443_row2_col1, #T_92443_row2_col3, #T_92443_row2_col7, #T_92443_row2_col9, #T_92443_row2_col11, #T_92443_row2_col13, #T_92443_row3_col1, #T_92443_row3_col17, #T_92443_row3_col19, #T_92443_row4_col1, #T_92443_row4_col3, #T_92443_row4_col15, #T_92443_row4_col17, #T_92443_row4_col19, #T_92443_row5_col5, #T_92443_row5_col9, #T_92443_row5_col11, #T_92443_row5_col13, #T_92443_row5_col15, #T_92443_row5_col17, #T_92443_row5_col19 {
#   background-color: red;
# }
# </style>
# <table id="T_92443">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92443_level0_col0" class="col_heading level0 col0" colspan="2">231-194</th>
#       <th id="T_92443_level0_col2" class="col_heading level0 col2" colspan="2">301-945</th>
#       <th id="T_92443_level0_col4" class="col_heading level0 col4" colspan="2">303-752</th>
#       <th id="T_92443_level0_col6" class="col_heading level0 col6" colspan="2">372-282</th>
#       <th id="T_92443_level0_col8" class="col_heading level0 col8" colspan="2">410-601</th>
#       <th id="T_92443_level0_col10" class="col_heading level0 col10" colspan="2">432-296</th>
#       <th id="T_92443_level0_col12" class="col_heading level0 col12" colspan="2">442-286</th>
#       <th id="T_92443_level0_col14" class="col_heading level0 col14" colspan="2">770-300</th>
#       <th id="T_92443_level0_col16" class="col_heading level0 col16" colspan="2">780-770</th>
#       <th id="T_92443_level0_col18" class="col_heading level0 col18" colspan="2">917-841</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_92443_level1_col0" class="col_heading level1 col0" >ARIMA</th>
#       <th id="T_92443_level1_col1" class="col_heading level1 col1" >TRAC</th>
#       <th id="T_92443_level1_col2" class="col_heading level1 col2" >ARIMA</th>
#       <th id="T_92443_level1_col3" class="col_heading level1 col3" >TRAC</th>
#       <th id="T_92443_level1_col4" class="col_heading level1 col4" >ARIMA</th>
#       <th id="T_92443_level1_col5" class="col_heading level1 col5" >TRAC</th>
#       <th id="T_92443_level1_col6" class="col_heading level1 col6" >ARIMA</th>
#       <th id="T_92443_level1_col7" class="col_heading level1 col7" >TRAC</th>
#       <th id="T_92443_level1_col8" class="col_heading level1 col8" >ARIMA</th>
#       <th id="T_92443_level1_col9" class="col_heading level1 col9" >TRAC</th>
#       <th id="T_92443_level1_col10" class="col_heading level1 col10" >ARIMA</th>
#       <th id="T_92443_level1_col11" class="col_heading level1 col11" >TRAC</th>
#       <th id="T_92443_level1_col12" class="col_heading level1 col12" >ARIMA</th>
#       <th id="T_92443_level1_col13" class="col_heading level1 col13" >TRAC</th>
#       <th id="T_92443_level1_col14" class="col_heading level1 col14" >ARIMA</th>
#       <th id="T_92443_level1_col15" class="col_heading level1 col15" >TRAC</th>
#       <th id="T_92443_level1_col16" class="col_heading level1 col16" >ARIMA</th>
#       <th id="T_92443_level1_col17" class="col_heading level1 col17" >TRAC</th>
#       <th id="T_92443_level1_col18" class="col_heading level1 col18" >ARIMA</th>
#       <th id="T_92443_level1_col19" class="col_heading level1 col19" >TRAC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92443_level0_row0" class="row_heading level0 row0" >2019-09-13 00:00:00</th>
#       <td id="T_92443_row0_col0" class="data row0 col0" >up</td>
#       <td id="T_92443_row0_col1" class="data row0 col1" >down</td>
#       <td id="T_92443_row0_col2" class="data row0 col2" >stable</td>
#       <td id="T_92443_row0_col3" class="data row0 col3" >stable</td>
#       <td id="T_92443_row0_col4" class="data row0 col4" >stable</td>
#       <td id="T_92443_row0_col5" class="data row0 col5" >stable</td>
#       <td id="T_92443_row0_col6" class="data row0 col6" >up</td>
#       <td id="T_92443_row0_col7" class="data row0 col7" >up</td>
#       <td id="T_92443_row0_col8" class="data row0 col8" >up</td>
#       <td id="T_92443_row0_col9" class="data row0 col9" >up</td>
#       <td id="T_92443_row0_col10" class="data row0 col10" >up</td>
#       <td id="T_92443_row0_col11" class="data row0 col11" >up</td>
#       <td id="T_92443_row0_col12" class="data row0 col12" >up</td>
#       <td id="T_92443_row0_col13" class="data row0 col13" >up</td>
#       <td id="T_92443_row0_col14" class="data row0 col14" >down</td>
#       <td id="T_92443_row0_col15" class="data row0 col15" >stable</td>
#       <td id="T_92443_row0_col16" class="data row0 col16" >stable</td>
#       <td id="T_92443_row0_col17" class="data row0 col17" >down</td>
#       <td id="T_92443_row0_col18" class="data row0 col18" >stable</td>
#       <td id="T_92443_row0_col19" class="data row0 col19" >down</td>
#     </tr>
#     <tr>
#       <th id="T_92443_level0_row1" class="row_heading level0 row1" >2020-07-10 00:00:00</th>
#       <td id="T_92443_row1_col0" class="data row1 col0" >up</td>
#       <td id="T_92443_row1_col1" class="data row1 col1" >up</td>
#       <td id="T_92443_row1_col2" class="data row1 col2" >up</td>
#       <td id="T_92443_row1_col3" class="data row1 col3" >up</td>
#       <td id="T_92443_row1_col4" class="data row1 col4" >up</td>
#       <td id="T_92443_row1_col5" class="data row1 col5" >up</td>
#       <td id="T_92443_row1_col6" class="data row1 col6" >up</td>
#       <td id="T_92443_row1_col7" class="data row1 col7" >up</td>
#       <td id="T_92443_row1_col8" class="data row1 col8" >up</td>
#       <td id="T_92443_row1_col9" class="data row1 col9" >up</td>
#       <td id="T_92443_row1_col10" class="data row1 col10" >up</td>
#       <td id="T_92443_row1_col11" class="data row1 col11" >up</td>
#       <td id="T_92443_row1_col12" class="data row1 col12" >up</td>
#       <td id="T_92443_row1_col13" class="data row1 col13" >up</td>
#       <td id="T_92443_row1_col14" class="data row1 col14" >up</td>
#       <td id="T_92443_row1_col15" class="data row1 col15" >up</td>
#       <td id="T_92443_row1_col16" class="data row1 col16" >down</td>
#       <td id="T_92443_row1_col17" class="data row1 col17" >down</td>
#       <td id="T_92443_row1_col18" class="data row1 col18" >up</td>
#       <td id="T_92443_row1_col19" class="data row1 col19" >up</td>
#     </tr>
#     <tr>
#       <th id="T_92443_level0_row2" class="row_heading level0 row2" >2021-08-27 00:00:00</th>
#       <td id="T_92443_row2_col0" class="data row2 col0" >stable</td>
#       <td id="T_92443_row2_col1" class="data row2 col1" >down</td>
#       <td id="T_92443_row2_col2" class="data row2 col2" >stable</td>
#       <td id="T_92443_row2_col3" class="data row2 col3" >down</td>
#       <td id="T_92443_row2_col4" class="data row2 col4" >stable</td>
#       <td id="T_92443_row2_col5" class="data row2 col5" >stable</td>
#       <td id="T_92443_row2_col6" class="data row2 col6" >stable</td>
#       <td id="T_92443_row2_col7" class="data row2 col7" >up</td>
#       <td id="T_92443_row2_col8" class="data row2 col8" >stable</td>
#       <td id="T_92443_row2_col9" class="data row2 col9" >up</td>
#       <td id="T_92443_row2_col10" class="data row2 col10" >up</td>
#       <td id="T_92443_row2_col11" class="data row2 col11" >stable</td>
#       <td id="T_92443_row2_col12" class="data row2 col12" >stable</td>
#       <td id="T_92443_row2_col13" class="data row2 col13" >up</td>
#       <td id="T_92443_row2_col14" class="data row2 col14" >stable</td>
#       <td id="T_92443_row2_col15" class="data row2 col15" >stable</td>
#       <td id="T_92443_row2_col16" class="data row2 col16" >stable</td>
#       <td id="T_92443_row2_col17" class="data row2 col17" >stable</td>
#       <td id="T_92443_row2_col18" class="data row2 col18" >down</td>
#       <td id="T_92443_row2_col19" class="data row2 col19" >down</td>
#     </tr>
#     <tr>
#       <th id="T_92443_level0_row3" class="row_heading level0 row3" >2022-04-22 00:00:00</th>
#       <td id="T_92443_row3_col0" class="data row3 col0" >stable</td>
#       <td id="T_92443_row3_col1" class="data row3 col1" >down</td>
#       <td id="T_92443_row3_col2" class="data row3 col2" >down</td>
#       <td id="T_92443_row3_co

# %% [markdown]
# ### Final conclusion:
#
# * ARIMA strategy captures the patterns and trends of the data using a combination of past values (AR), differences (I), and errors (MA);
#
# * The probability of ARIMA displaying a serious error is relatively low.
#
# * Market conditions are correlated with the performance of predicted trends:
#   * In a downtrend scenario (Range 2), volatility increases rapidly, may explai why there is an increase.
